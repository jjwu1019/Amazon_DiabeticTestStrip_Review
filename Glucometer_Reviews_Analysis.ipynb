# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#load csv
review_df = pd.read_csv("glucometer_review_raw.csv")
review_df
# Out:
#            asin                                   url     score  sponsored  \
# 0    B076VSN7TR  https://www.amazon.com/dp/B076VSN7TR  124264.4      False
# 1    B06WD5HRM8  https://www.amazon.com/dp/B06WD5HRM8    5322.2      False
# 2    B087NPJX1W  https://www.amazon.com/dp/B087NPJX1W   28358.4      False
# 3    B07VB22PNT  https://www.amazon.com/dp/B07VB22PNT    2707.2      False
# 4    B07TVLNL4Q  https://www.amazon.com/dp/B07TVLNL4Q   32453.0      False
# ..          ...                                   ...       ...        ...
# 203  B008MU09EC  https://www.amazon.com/dp/B008MU09EC     409.4      False
# 204  B00QH65O48  https://www.amazon.com/dp/B00QH65O48     662.4      False
# 205  B01GU3SKZM  https://www.amazon.com/dp/B01GU3SKZM    4213.6      False
# 206  B093GK1VYD  https://www.amazon.com/dp/B093GK1VYD     198.0      False
# 207  B00KBZ4Y5G  https://www.amazon.com/dp/B00KBZ4Y5G     931.5      False
#
#      amazonChoice  bestSeller  amazonPrime  \
# 0           False        True         True
# 1           False       False        False
# 2           False       False        False
# 3           False       False         True
# 4           False       False         True
# ..            ...         ...          ...
# 203         False       False        False
# 204         False       False        False
# 205         False       False        False
# 206         False       False         True
# 207         False       False        False
#
#                                                  title  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...
# 1    Easy Touch Eas-150 Easytouch Glucose Test Stri...
# 2    Accu-Chek Guide Test Strips for Diabetic Blood...
# 3    Metene TD-4116 Blood Glucose Test Strips, 100 ...
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...
# ..                                                 ...
# 203  Diabetes Testing Kit Glucose Testing Kit inclu...
# 204  Abbott Freestyle Lite Blood Glucose Meter with...
# 205  True Decor TrueMetrix Self Monitoring Blood Gl...
# 206  Sponsored Ad - Blood Glucose Monitor - Diabete...
# 207  Sponsored Ad - A1CNow+ System (Monitor w/20 St...
#
#                                              thumbnail  position.page  \
# 0    https://m.media-amazon.com/images/I/81EZb2+YuK...              1
# 1    https://m.media-amazon.com/images/I/51wBoCNWj3...              1
# 2    https://m.media-amazon.com/images/I/71imFW8YsA...              1
# 3    https://m.media-amazon.com/images/I/71160PqPGP...              1
# 4    https://m.media-amazon.com/images/I/71V3ihtTar...              1
# ..                                                 ...            ...
# 203  https://m.media-amazon.com/images/I/51CQA4fxkN...              1
# 204  https://m.media-amazon.com/images/I/61Xpt4QmBu...              1
# 205  https://m.media-amazon.com/images/I/810RZIxG3q...              1
# 206  https://m.media-amazon.com/images/I/71pre-8ou3...              1
# 207  https://m.media-amazon.com/images/I/310x7pg7FI...              1
#
#      position.position  position.global_position  price.discounted  \
# 0                    1                         1             False
# 1                    2                         2             False
# 2                    3                         3             False
# 3                    4                         4             False
# 4                    5                         5              True
# ..                 ...                       ...               ...
# 203                 52                        52             False
# 204                 53                        53             False
# 205                 55                        55              True
# 206                 56                        56             False
# 207                 57                        57             False
#
#      price.current_price price.currency  price.before_price  \
# 0                      0            USD                0.00
# 1                      0            USD                0.00
# 2                      0            USD                0.00
# 3                      0            USD                0.00
# 4                      0            USD               28.99
# ..                   ...            ...                 ...
# 203                    0            USD                0.00
# 204                    0            USD                0.00
# 205                    0            USD               10.80
# 206                    0            USD                0.00
# 207                    0            USD                0.00
#
#      price.savings_amount  price.savings_percent  reviews.total_reviews  \
# 0                    0.00                      0                  27014
# 1                    0.00                      0                   1157
# 2                    0.00                      0                   5908
# 3                    0.00                      0                    576
# 4                   28.99                    100                   7055
# ..                    ...                    ...                    ...
# 203                  0.00                      0                     89
# 204                  0.00                      0                    144
# 205                 10.80                    100                    916
# 206                  0.00                      0                     44
# 207                  0.00                      0                    207
#
#      reviews.rating
# 0               4.6
# 1               4.6
# 2               4.8
# 3               4.7
# 4               4.6
# ..              ...
# 203             4.6
# 204             4.6
# 205             4.6
# 206             4.5
# 207             4.5
#
# [208 rows x 20 columns]

# %%
df = review_df.drop_duplicates()
df = df.drop_duplicates(subset=['reviews.total_reviews'])
df
# Out:
#            asin                                   url     score  sponsored  \
# 0    B076VSN7TR  https://www.amazon.com/dp/B076VSN7TR  124264.4      False
# 1    B06WD5HRM8  https://www.amazon.com/dp/B06WD5HRM8    5322.2      False
# 2    B087NPJX1W  https://www.amazon.com/dp/B087NPJX1W   28358.4      False
# 3    B07VB22PNT  https://www.amazon.com/dp/B07VB22PNT    2707.2      False
# 4    B07TVLNL4Q  https://www.amazon.com/dp/B07TVLNL4Q   32453.0      False
# ..          ...                                   ...       ...        ...
# 195  B08FXTPCGG  https://www.amazon.com/dp/B08FXTPCGG    2695.6      False
# 196  B08RK5C29F  https://www.amazon.com/dp/B08RK5C29F     219.3      False
# 203  B008MU09EC  https://www.amazon.com/dp/B008MU09EC     409.4      False
# 205  B01GU3SKZM  https://www.amazon.com/dp/B01GU3SKZM    4213.6      False
# 207  B00KBZ4Y5G  https://www.amazon.com/dp/B00KBZ4Y5G     931.5      False
#
#      amazonChoice  bestSeller  amazonPrime  \
# 0           False        True         True
# 1           False       False        False
# 2           False       False        False
# 3           False       False         True
# 4           False       False         True
# ..            ...         ...          ...
# 195         False       False        False
# 196         False       False         True
# 203         False       False        False
# 205         False       False        False
# 207         False       False        False
#
#                                                  title  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...
# 1    Easy Touch Eas-150 Easytouch Glucose Test Stri...
# 2    Accu-Chek Guide Test Strips for Diabetic Blood...
# 3    Metene TD-4116 Blood Glucose Test Strips, 100 ...
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...
# ..                                                 ...
# 195  OneTouch Verio Reflect Blood Glucose Meter | G...
# 196  CURO G10 Glucose Home Test Kit - Device and Se...
# 203  Diabetes Testing Kit Glucose Testing Kit inclu...
# 205  True Decor TrueMetrix Self Monitoring Blood Gl...
# 207  Sponsored Ad - A1CNow+ System (Monitor w/20 St...
#
#                                              thumbnail  position.page  \
# 0    https://m.media-amazon.com/images/I/81EZb2+YuK...              1
# 1    https://m.media-amazon.com/images/I/51wBoCNWj3...              1
# 2    https://m.media-amazon.com/images/I/71imFW8YsA...              1
# 3    https://m.media-amazon.com/images/I/71160PqPGP...              1
# 4    https://m.media-amazon.com/images/I/71V3ihtTar...              1
# ..                                                 ...            ...
# 195  https://m.media-amazon.com/images/I/71H8gArTZj...              1
# 196  https://m.media-amazon.com/images/I/51srjRIWUJ...              1
# 203  https://m.media-amazon.com/images/I/51CQA4fxkN...              1
# 205  https://m.media-amazon.com/images/I/810RZIxG3q...              1
# 207  https://m.media-amazon.com/images/I/310x7pg7FI...              1
#
#      position.position  position.global_position  price.discounted  \
# 0                    1                         1             False
# 1                    2                         2             False
# 2                    3                         3             False
# 3                    4                         4             False
# 4                    5                         5              True
# ..                 ...                       ...               ...
# 195                 41                        41              True
# 196                 42                        42             False
# 203                 52                        52             False
# 205                 55                        55              True
# 207                 57                        57             False
#
#      price.current_price price.currency  price.before_price  \
# 0                      0            USD                0.00
# 1                      0            USD                0.00
# 2                      0            USD                0.00
# 3                      0            USD                0.00
# 4                      0            USD               28.99
# ..                   ...            ...                 ...
# 195                    0            USD               29.99
# 196                    0            USD                0.00
# 203                    0            USD                0.00
# 205                    0            USD               10.80
# 207                    0            USD                0.00
#
#      price.savings_amount  price.savings_percent  reviews.total_reviews  \
# 0                    0.00                      0                  27014
# 1                    0.00                      0                   1157
# 2                    0.00                      0                   5908
# 3                    0.00                      0                    576
# 4                   28.99                    100                   7055
# ..                    ...                    ...                    ...
# 195                 29.99                    100                    586
# 196                  0.00                      0                     51
# 203                  0.00                      0                     89
# 205                 10.80                    100                    916
# 207                  0.00                      0                    207
#
#      reviews.rating
# 0               4.6
# 1               4.6
# 2               4.8
# 3               4.7
# 4               4.6
# ..              ...
# 195             4.6
# 196             4.3
# 203             4.6
# 205             4.6
# 207             4.5
#
# [153 rows x 20 columns]

# %%
df = df[['title', 'bestSeller', 'amazonPrime', 'score','reviews.total_reviews', 'reviews.rating', 'asin', 'url']]
df
# Out:
#                                                  title  bestSeller  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...        True
# 1    Easy Touch Eas-150 Easytouch Glucose Test Stri...       False
# 2    Accu-Chek Guide Test Strips for Diabetic Blood...       False
# 3    Metene TD-4116 Blood Glucose Test Strips, 100 ...       False
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...       False
# ..                                                 ...         ...
# 195  OneTouch Verio Reflect Blood Glucose Meter | G...       False
# 196  CURO G10 Glucose Home Test Kit - Device and Se...       False
# 203  Diabetes Testing Kit Glucose Testing Kit inclu...       False
# 205  True Decor TrueMetrix Self Monitoring Blood Gl...       False
# 207  Sponsored Ad - A1CNow+ System (Monitor w/20 St...       False
#
#      amazonPrime     score  reviews.total_reviews  reviews.rating        asin  \
# 0           True  124264.4                  27014             4.6  B076VSN7TR
# 1          False    5322.2                   1157             4.6  B06WD5HRM8
# 2          False   28358.4                   5908             4.8  B087NPJX1W
# 3           True    2707.2                    576             4.7  B07VB22PNT
# 4           True   32453.0                   7055             4.6  B07TVLNL4Q
# ..           ...       ...                    ...             ...         ...
# 195        False    2695.6                    586             4.6  B08FXTPCGG
# 196         True     219.3                     51             4.3  B08RK5C29F
# 203        False     409.4                     89             4.6  B008MU09EC
# 205        False    4213.6                    916             4.6  B01GU3SKZM
# 207        False     931.5                    207             4.5  B00KBZ4Y5G
#
#                                       url
# 0    https://www.amazon.com/dp/B076VSN7TR
# 1    https://www.amazon.com/dp/B06WD5HRM8
# 2    https://www.amazon.com/dp/B087NPJX1W
# 3    https://www.amazon.com/dp/B07VB22PNT
# 4    https://www.amazon.com/dp/B07TVLNL4Q
# ..                                    ...
# 195  https://www.amazon.com/dp/B08FXTPCGG
# 196  https://www.amazon.com/dp/B08RK5C29F
# 203  https://www.amazon.com/dp/B008MU09EC
# 205  https://www.amazon.com/dp/B01GU3SKZM
# 207  https://www.amazon.com/dp/B00KBZ4Y5G
#
# [153 rows x 8 columns]

# %%
df = df.sort_values(by=['reviews.total_reviews'], ascending=False)
df
# Out:
#                                                  title  bestSeller  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...        True
# 39   TRUE METRIX Blood Glucose Test Strips NFRS 100...       False
# 38   DARIO Blood Glucose Monitor Kit Test Your Bloo...       False
# 5    Care Touch Blood Glucose Test Strips for Diabe...       False
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...       False
# ..                                                 ...         ...
# 127  TRUE METRIX® GO Starter Kit with TRUE METRIX® ...       False
# 93   Accu-Chek Aviva Plus Test Strips -100 ct, Pack...       False
# 190  latulipo Blood Glucose Monitor Kit, with 1 Blo...       False
# 193  3in1 Easytouch Glucose Cholesterol Uric Acid M...       False
# 169  Accu-Chek Aviva Plus Test Strips - 50 ct, Pack...       False
#
#      amazonPrime     score  reviews.total_reviews  reviews.rating        asin  \
# 0           True  124264.4                  27014             4.6  B076VSN7TR
# 39          True   50635.2                  10549             4.8  B085WBVJZZ
# 38          True   41039.2                   9544             4.3  B07G3BNXR6
# 5           True   45470.4                   9473             4.8  B0794DFH6F
# 4           True   32453.0                   7055             4.6  B07TVLNL4Q
# ..           ...       ...                    ...             ...         ...
# 127         True      30.0                      6             5.0  B08KC5RN48
# 93         False      25.0                      5             5.0  B00FQF779Q
# 190         True      16.4                      4             4.1  B09Q32P2H9
# 193        False      12.6                      3             4.2  B08L2XX2BX
# 169        False      10.0                      2             5.0  B078YG5RK8
#
#                                       url
# 0    https://www.amazon.com/dp/B076VSN7TR
# 39   https://www.amazon.com/dp/B085WBVJZZ
# 38   https://www.amazon.com/dp/B07G3BNXR6
# 5    https://www.amazon.com/dp/B0794DFH6F
# 4    https://www.amazon.com/dp/B07TVLNL4Q
# ..                                    ...
# 127  https://www.amazon.com/dp/B08KC5RN48
# 93   https://www.amazon.com/dp/B00FQF779Q
# 190  https://www.amazon.com/dp/B09Q32P2H9
# 193  https://www.amazon.com/dp/B08L2XX2BX
# 169  https://www.amazon.com/dp/B078YG5RK8
#
# [153 rows x 8 columns]

# %%
df[df['title'].str.contains("Sponsored Ad - ")]
# Out:
#                                                  title  bestSeller  \
# 48   Sponsored Ad - Care Touch Multi Colored Diabet...       False
# 50   Sponsored Ad - Care Touch Multi Colored Diabet...       False
# 186  Sponsored Ad - Care Touch Blood Glucose Test S...       False
# 101  Sponsored Ad - CheckUp 10 Parameters Urine Tes...       False
# 105  Sponsored Ad - Care Touch Diabetic Lancets 30 ...       False
# 165  Sponsored Ad - DISONCARE 60H 2 Insulin Pen Coo...       False
# 207  Sponsored Ad - A1CNow+ System (Monitor w/20 St...       False
# 100  Sponsored Ad - Agrose Blood Glucose Monitor Ki...       False
#
#      amazonPrime    score  reviews.total_reviews  reviews.rating        asin  \
# 48          True  25867.2                   5389             4.8  B07199BSMC
# 50          True  13161.6                   2742             4.8  B071RYXFG8
# 186         True   9898.2                   2106             4.7  B076VSWYZF
# 101         True   1681.3                    391             4.3  B087H8XM5L
# 105         True   1348.8                    281             4.8  B01GGGS8BE
# 165         True   1212.6                    258             4.7  B07MT5C8ZL
# 207        False    931.5                    207             4.5  B00KBZ4Y5G
# 100         True     52.8                     12             4.4  B09NR96K3D
#
#                                       url
# 48   https://www.amazon.com/dp/B07199BSMC
# 50   https://www.amazon.com/dp/B071RYXFG8
# 186  https://www.amazon.com/dp/B076VSWYZF
# 101  https://www.amazon.com/dp/B087H8XM5L
# 105  https://www.amazon.com/dp/B01GGGS8BE
# 165  https://www.amazon.com/dp/B07MT5C8ZL
# 207  https://www.amazon.com/dp/B00KBZ4Y5G
# 100  https://www.amazon.com/dp/B09NR96K3D

# %%
df["title"] = df["title"].str.replace("Sponsored Ad - ", "")

# %%
df[['brand1', 'brand2', 'spec']] = df['title'].str.split(' ', 2, expand=True)

# %%
df['brand'] = df[['brand1', 'brand2']].agg(' '.join, axis=1)

# %%
df
# Out:
#                                                  title  bestSeller  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...        True
# 39   TRUE METRIX Blood Glucose Test Strips NFRS 100...       False
# 38   DARIO Blood Glucose Monitor Kit Test Your Bloo...       False
# 5    Care Touch Blood Glucose Test Strips for Diabe...       False
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...       False
# ..                                                 ...         ...
# 127  TRUE METRIX® GO Starter Kit with TRUE METRIX® ...       False
# 93   Accu-Chek Aviva Plus Test Strips -100 ct, Pack...       False
# 190  latulipo Blood Glucose Monitor Kit, with 1 Blo...       False
# 193  3in1 Easytouch Glucose Cholesterol Uric Acid M...       False
# 169  Accu-Chek Aviva Plus Test Strips - 50 ct, Pack...       False
#
#      amazonPrime     score  reviews.total_reviews  reviews.rating        asin  \
# 0           True  124264.4                  27014             4.6  B076VSN7TR
# 39          True   50635.2                  10549             4.8  B085WBVJZZ
# 38          True   41039.2                   9544             4.3  B07G3BNXR6
# 5           True   45470.4                   9473             4.8  B0794DFH6F
# 4           True   32453.0                   7055             4.6  B07TVLNL4Q
# ..           ...       ...                    ...             ...         ...
# 127         True      30.0                      6             5.0  B08KC5RN48
# 93         False      25.0                      5             5.0  B00FQF779Q
# 190         True      16.4                      4             4.1  B09Q32P2H9
# 193        False      12.6                      3             4.2  B08L2XX2BX
# 169        False      10.0                      2             5.0  B078YG5RK8
#
#                                       url     brand1     brand2  \
# 0    https://www.amazon.com/dp/B076VSN7TR      Blood    Glucose
# 39   https://www.amazon.com/dp/B085WBVJZZ       TRUE     METRIX
# 38   https://www.amazon.com/dp/B07G3BNXR6      DARIO      Blood
# 5    https://www.amazon.com/dp/B0794DFH6F       Care      Touch
# 4    https://www.amazon.com/dp/B07TVLNL4Q      AUVON      Blood
# ..                                    ...        ...        ...
# 127  https://www.amazon.com/dp/B08KC5RN48       TRUE    METRIX®
# 93   https://www.amazon.com/dp/B00FQF779Q  Accu-Chek      Aviva
# 190  https://www.amazon.com/dp/B09Q32P2H9   latulipo      Blood
# 193  https://www.amazon.com/dp/B08L2XX2BX       3in1  Easytouch
# 169  https://www.amazon.com/dp/B078YG5RK8  Accu-Chek      Aviva
#
#                                                   spec            brand
# 0    Monitor Kit - Diabetes Testing Kit with 1 Gluc...    Blood Glucose
# 39   Blood Glucose Test Strips NFRS 100ct (100 Test...      TRUE METRIX
# 38   Glucose Monitor Kit Test Your Blood Sugar Leve...      DARIO Blood
# 5    Blood Glucose Test Strips for Diabetes I For U...       Care Touch
# 4    Sugar Test Kit, High-Tech Glucose Monitor, Dia...      AUVON Blood
# ..                                                 ...              ...
# 127  GO Starter Kit with TRUE METRIX® Test Strips a...     TRUE METRIX®
# 93                 Plus Test Strips -100 ct, Pack of 3  Accu-Chek Aviva
# 190  Glucose Monitor Kit, with 1 Blood Sugar Test K...   latulipo Blood
# 193  Glucose Cholesterol Uric Acid Monitor Test Str...   3in1 Easytouch
# 169                Plus Test Strips - 50 ct, Pack of 5  Accu-Chek Aviva
#
# [153 rows x 12 columns]

# %%
df["brand"] = df["brand"].str.replace("Blood Glucose", "Care Touch")
df["brand"] = df["brand"].str.replace("6 x", "TRUE METRIX®")
df = df.rename(columns={"reviews.total_reviews": "total_reviews", "reviews.rating": "rating"})
df
# Out:
#                                                  title  bestSeller  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...        True
# 39   TRUE METRIX Blood Glucose Test Strips NFRS 100...       False
# 38   DARIO Blood Glucose Monitor Kit Test Your Bloo...       False
# 5    Care Touch Blood Glucose Test Strips for Diabe...       False
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...       False
# ..                                                 ...         ...
# 127  TRUE METRIX® GO Starter Kit with TRUE METRIX® ...       False
# 93   Accu-Chek Aviva Plus Test Strips -100 ct, Pack...       False
# 190  latulipo Blood Glucose Monitor Kit, with 1 Blo...       False
# 193  3in1 Easytouch Glucose Cholesterol Uric Acid M...       False
# 169  Accu-Chek Aviva Plus Test Strips - 50 ct, Pack...       False
#
#      amazonPrime     score  total_reviews  rating        asin  \
# 0           True  124264.4          27014     4.6  B076VSN7TR
# 39          True   50635.2          10549     4.8  B085WBVJZZ
# 38          True   41039.2           9544     4.3  B07G3BNXR6
# 5           True   45470.4           9473     4.8  B0794DFH6F
# 4           True   32453.0           7055     4.6  B07TVLNL4Q
# ..           ...       ...            ...     ...         ...
# 127         True      30.0              6     5.0  B08KC5RN48
# 93         False      25.0              5     5.0  B00FQF779Q
# 190         True      16.4              4     4.1  B09Q32P2H9
# 193        False      12.6              3     4.2  B08L2XX2BX
# 169        False      10.0              2     5.0  B078YG5RK8
#
#                                       url     brand1     brand2  \
# 0    https://www.amazon.com/dp/B076VSN7TR      Blood    Glucose
# 39   https://www.amazon.com/dp/B085WBVJZZ       TRUE     METRIX
# 38   https://www.amazon.com/dp/B07G3BNXR6      DARIO      Blood
# 5    https://www.amazon.com/dp/B0794DFH6F       Care      Touch
# 4    https://www.amazon.com/dp/B07TVLNL4Q      AUVON      Blood
# ..                                    ...        ...        ...
# 127  https://www.amazon.com/dp/B08KC5RN48       TRUE    METRIX®
# 93   https://www.amazon.com/dp/B00FQF779Q  Accu-Chek      Aviva
# 190  https://www.amazon.com/dp/B09Q32P2H9   latulipo      Blood
# 193  https://www.amazon.com/dp/B08L2XX2BX       3in1  Easytouch
# 169  https://www.amazon.com/dp/B078YG5RK8  Accu-Chek      Aviva
#
#                                                   spec            brand
# 0    Monitor Kit - Diabetes Testing Kit with 1 Gluc...       Care Touch
# 39   Blood Glucose Test Strips NFRS 100ct (100 Test...      TRUE METRIX
# 38   Glucose Monitor Kit Test Your Blood Sugar Leve...      DARIO Blood
# 5    Blood Glucose Test Strips for Diabetes I For U...       Care Touch
# 4    Sugar Test Kit, High-Tech Glucose Monitor, Dia...      AUVON Blood
# ..                                                 ...              ...
# 127  GO Starter Kit with TRUE METRIX® Test Strips a...     TRUE METRIX®
# 93                 Plus Test Strips -100 ct, Pack of 3  Accu-Chek Aviva
# 190  Glucose Monitor Kit, with 1 Blood Sugar Test K...   latulipo Blood
# 193  Glucose Cholesterol Uric Acid Monitor Test Str...   3in1 Easytouch
# 169                Plus Test Strips - 50 ct, Pack of 5  Accu-Chek Aviva
#
# [153 rows x 12 columns]

# %%
df.to_csv("glucometer_review_clean_v1.csv", index=False, header=True)

# %%
filter_df = df.loc[(df['total_reviews'] >= 2500)]
filter_df
# Out:
#                                                  title  bestSeller  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...        True
# 39   TRUE METRIX Blood Glucose Test Strips NFRS 100...       False
# 38   DARIO Blood Glucose Monitor Kit Test Your Bloo...       False
# 5    Care Touch Blood Glucose Test Strips for Diabe...       False
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...       False
# 20    CONTOUR NEXT Blood Glucose Test Strips, 70 Count        True
# 2    Accu-Chek Guide Test Strips for Diabetic Blood...       False
# 48   Care Touch Multi Colored Diabetic Lancets 30 G...       False
# 56   KETO-MOJO GK+ Bluetooth Glucose & Ketone Testi...       False
# 24         Freestyle lite glucose test strips 50 count       False
# 136  Dario 100 Blood Glucose No Coding Needed Test ...       False
# 17   Accu-Chek Instant S Glucometer with Free Test ...       False
# 122  ReliOn Prime Blood Glucose Test Strips, 100 Co...       False
# 44   Prodigy Glucose Monitor Kit - Includes Prodigy...       False
# 8    AUVON I-QARE DS-W Draw-in Blood Glucose Test S...       False
# 47   KETO-MOJO Test Strip Combo Pack for Use ONLY w...       False
# 99     AlphaTRAK 2 Blood Glucose Monitoring System Kit       False
# 11   Blood Glucose Monitor Kit - Diabetes Testing K...       False
# 22   OneTouch Verio Test Strips for Diabetes Value ...       False
# 46   6 x 50 ct TRUE METRIX® NFRS Test Strips (300 T...       False
# 9    AUVON High-Tech Blood Sugar Test Kit, Diabetes...       False
# 36   OneTouch Verio Test Strips for Diabetes - 30 C...       False
# 134  The CONTOUR NEXT ONE Blood Glucose Monitoring ...       False
# 45   Contour Next EZ Diabetes Testing Kit | Contour...       False
# 50   Care Touch Multi Colored Diabetic Lancets 30 G...       False
# 53   Oh’Care Lite Blood Sugar Test Kit – Blood Gluc...       False
#
#      amazonPrime     score  total_reviews  rating        asin  \
# 0           True  124264.4          27014     4.6  B076VSN7TR
# 39          True   50635.2          10549     4.8  B085WBVJZZ
# 38          True   41039.2           9544     4.3  B07G3BNXR6
# 5           True   45470.4           9473     4.8  B0794DFH6F
# 4           True   32453.0           7055     4.6  B07TVLNL4Q
# 20         False   33825.6           7047     4.8  B07CF8C4VX
# 2          False   28358.4           5908     4.8  B087NPJX1W
# 48          True   25867.2           5389     4.8  B07199BSMC
# 56          True   24088.5           5353     4.5  B08G5BZQVL
# 24         False   23424.8           4984     4.7  B075VD1JTW
# 136         True   21756.3           4629     4.7  B07JPYMWYZ
# 17          True   18627.0           4435     4.2  B07B6LYFV4
# 122        False   19848.0           4135     4.8  B018F4BVDM
# 44          True   18754.2           4077     4.6  B07S2T64BL
# 8           True   18196.8           3791     4.8  B07Z3RX8F1
# 47          True   16548.7           3521     4.7  B08G5CW8RF
# 99          True   14967.0           3326     4.5  B007Z0XULY
# 11         False   15203.0           3305     4.6  B07G783R7X
# 22          True   15792.0           3290     4.8  B08L473F6W
# 46          True   15393.6           3207     4.8  B01LW1A51V
# 9           True   14582.0           3170     4.6  B081ZY1LHV
# 36          True   13606.5           2895     4.7  B08FXRYSPG
# 134        False   13564.2           2886     4.7  B06W53ZLTK
# 45          True   12811.0           2785     4.6  B00NG0MSPQ
# 50          True   13161.6           2742     4.8  B071RYXFG8
# 53          True   12019.5           2671     4.5  B084WN1HK7
#
#                                       url     brand1     brand2  \
# 0    https://www.amazon.com/dp/B076VSN7TR      Blood    Glucose
# 39   https://www.amazon.com/dp/B085WBVJZZ       TRUE     METRIX
# 38   https://www.amazon.com/dp/B07G3BNXR6      DARIO      Blood
# 5    https://www.amazon.com/dp/B0794DFH6F       Care      Touch
# 4    https://www.amazon.com/dp/B07TVLNL4Q      AUVON      Blood
# 20   https://www.amazon.com/dp/B07CF8C4VX    CONTOUR       NEXT
# 2    https://www.amazon.com/dp/B087NPJX1W  Accu-Chek      Guide
# 48   https://www.amazon.com/dp/B07199BSMC       Care      Touch
# 56   https://www.amazon.com/dp/B08G5BZQVL  KETO-MOJO        GK+
# 24   https://www.amazon.com/dp/B075VD1JTW  Freestyle       lite
# 136  https://www.amazon.com/dp/B07JPYMWYZ      Dario        100
# 17   https://www.amazon.com/dp/B07B6LYFV4  Accu-Chek    Instant
# 122  https://www.amazon.com/dp/B018F4BVDM     ReliOn      Prime
# 44   https://www.amazon.com/dp/B07S2T64BL    Prodigy    Glucose
# 8    https://www.amazon.com/dp/B07Z3RX8F1      AUVON     I-QARE
# 47   https://www.amazon.com/dp/B08G5CW8RF  KETO-MOJO       Test
# 99   https://www.amazon.com/dp/B007Z0XULY  AlphaTRAK          2
# 11   https://www.amazon.com/dp/B07G783R7X      Blood    Glucose
# 22   https://www.amazon.com/dp/B08L473F6W   OneTouch      Verio
# 46   https://www.amazon.com/dp/B01LW1A51V          6          x
# 9    https://www.amazon.com/dp/B081ZY1LHV      AUVON  High-Tech
# 36   https://www.amazon.com/dp/B08FXRYSPG   OneTouch      Verio
# 134  https://www.amazon.com/dp/B06W53ZLTK        The    CONTOUR
# 45   https://www.amazon.com/dp/B00NG0MSPQ    Contour       Next
# 50   https://www.amazon.com/dp/B071RYXFG8       Care      Touch
# 53   https://www.amazon.com/dp/B084WN1HK7    Oh’Care       Lite
#
#                                                   spec              brand
# 0    Monitor Kit - Diabetes Testing Kit with 1 Gluc...         Care Touch
# 39   Blood Glucose Test Strips NFRS 100ct (100 Test...        TRUE METRIX
# 38   Glucose Monitor Kit Test Your Blood Sugar Leve...        DARIO Blood
# 5    Blood Glucose Test Strips for Diabetes I For U...         Care Touch
# 4    Sugar Test Kit, High-Tech Glucose Monitor, Dia...        AUVON Blood
# 20                 Blood Glucose Test Strips, 70 Count       CONTOUR NEXT
# 2    Test Strips for Diabetic Blood Glucose Testing...    Accu-Chek Guide
# 48   Multi Colored Diabetic Lancets 30 Gauge - Lanc...         Care Touch
# 56   Bluetooth Glucose & Ketone Testing Kit + Free ...      KETO-MOJO GK+
# 24                        glucose test strips 50 count     Freestyle lite
# 136  Blood Glucose No Coding Needed Test Strips Car...          Dario 100
# 17   S Glucometer with Free Test Strips, 10 Count (...  Accu-Chek Instant
# 122  Blood Glucose Test Strips, 100 Count, Single Pack       ReliOn Prime
# 44   Monitor Kit - Includes Prodigy Meter, 100ct te...    Prodigy Glucose
# 8    DS-W Draw-in Blood Glucose Test Strips (150 Co...       AUVON I-QARE
# 47   Strip Combo Pack for Use ONLY with The New GK+...     KETO-MOJO Test
# 99                 Blood Glucose Monitoring System Kit        AlphaTRAK 2
# 11   Monitor Kit - Diabetes Testing Kit with 1 Gluc...         Care Touch
# 22   Test Strips for Diabetes Value Pack - 60 Count...     OneTouch Verio
# 46   50 ct TRUE METRIX® NFRS Test Strips (300 Test ...       TRUE METRIX®
# 9    Blood Sugar Test Kit, Diabetes Glucose Monitor...    AUVON High-Tech
# 36   Test Strips for Diabetes - 30 Count | Diabetic...     OneTouch Verio
# 134           NEXT ONE Blood Glucose Monitoring System        The CONTOUR
# 45   EZ Diabetes Testing Kit | Contour Next EZ Bloo...       Contour Next
# 50   Multi Colored Diabetic Lancets 30 Gauge - Lanc...         Care Touch
# 53   Blood Sugar Test Kit – Blood Glucose Meter wit...       Oh’Care Lite

# %%
filter_df.plot.bar(x='brand', y=['total_reviews'], rot=90, title = 'Amazon Total Reviews (Glucometer)')
plt.savefig("Glucometer_Reviews.png" , dpi = 2400, bbox_inches = "tight")
