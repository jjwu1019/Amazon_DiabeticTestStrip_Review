# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import copy
import json

# %%
url = "https://amazon23.p.rapidapi.com/product-search"

querystring = {"query":"glucometer test strips","page":"1","country":"US"}

headers = {
	"X-RapidAPI-Host": "amazon23.p.rapidapi.com",
	"X-RapidAPI-Key": "f0470787e2msh2927b433c937eaep1a36a6jsn7ecc0efa9865"
}

response = requests.request("GET", url, headers=headers, params=querystring).json()

# %%
response
# Out:
# {'totalProducts': '332',
#  'category': 'aps',
#  'result': [{'position': {'page': 1, 'position': 1, 'global_position': 1},
#    'asin': 'B076VSN7TR',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 27014, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B076VSN7TR',
#    'score': '124264.40',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': True,
#    'amazonPrime': True,
#    'title': 'Blood Glucose Monitor Kit - Diabetes Testing Kit with 1 Glucometer, 100 Blood Sugar Test Strips, 1 Lancing Device, 100 Lan...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81EZb2+YuKL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 2, 'global_position': 2},
#    'asin': 'B06WD5HRM8',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1157, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B06WD5HRM8',
#    'score': '5322.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Easy Touch Eas-150 Easytouch Glucose Test Strip, 150 Count (Pack of 150)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/51wBoCNWj3L._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 3, 'global_position': 3},
#    'asin': 'B087NPJX1W',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 5908, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B087NPJX1W',
#    'score': '28358.40',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Accu-Chek Guide Test Strips for Diabetic Blood Glucose Testing (Pack of 100)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71imFW8YsAL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 4, 'global_position': 4},
#    'asin': 'B07VB22PNT',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 576, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B07VB22PNT',
#    'score': '2707.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Metene TD-4116 Blood Glucose Test Strips, 100 Count Blood Sugar Test Strips for Diabetes, Use with metene TD-4116 Blood Gl...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71160PqPGPL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 5, 'global_position': 5},
#    'asin': 'B07TVLNL4Q',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 28.99,
#     'savings_amount': 28.99,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 7055, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B07TVLNL4Q',
#    'score': '32453.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'AUVON Blood Sugar Test Kit, High-Tech Glucose Monitor, Diabetes Testing Kit with 50 Glucometer Strips and 50 30G Lancets, ...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71V3ihtTarL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 6, 'global_position': 6},
#    'asin': 'B0794DFH6F',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 9473, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B0794DFH6F',
#    'score': '45470.40',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Care Touch Blood Glucose Test Strips for Diabetes I For Use with Care Touch Blood Sugar Monitor - 1 Box of 100 Diabetic Te...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71xi00Rr7WS._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 7, 'global_position': 7},
#    'asin': 'B079NSYQN3',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 50,
#     'savings_amount': 50,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 1521, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B079NSYQN3',
#    'score': '7300.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': '5 x 50ct TRUE METRIX® NFRS Test Strips (250 Test Strips)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71r0dsIfBsL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 8, 'global_position': 8},
#    'asin': 'B07KCDCBFC',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 570, 'rating': 4.4},
#    'url': 'https://www.amazon.com/dp/B07KCDCBFC',
#    'score': '2508.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Reliable Diathrive Blood Sugar Test Kit & Blood Glucose Monitoring System – 4 Second Results! Glucometer/Glucose Meter Kit...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81uFA6SNCwL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 9, 'global_position': 9},
#    'asin': 'B07Z3RX8F1',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 3791, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B07Z3RX8F1',
#    'score': '18196.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'AUVON I-QARE DS-W Draw-in Blood Glucose Test Strips (150 Count) for use with AUVON DS-W Diabetes Sugar Testing Meter (No C...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71oxRLoqjpL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 10, 'global_position': 10},
#    'asin': 'B081ZY1LHV',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 35.99,
#     'savings_amount': 35.99,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 3170, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B081ZY1LHV',
#    'score': '14582.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'AUVON High-Tech Blood Sugar Test Kit, Diabetes Glucose Monitor with 100 Glucometer Strips, 100 Lancets and I-QARE DS-W Blo...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81qIlUsuT9L._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 11, 'global_position': 11},
#    'asin': 'B07Y1C68K7',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 481, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B07Y1C68K7',
#    'score': '2212.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'OneTouch Ultra 2 Blood Glucose Meter | Glucose Monitor For Blood Sugar Test Kit | Includes Blood Glucose Monitor, Lancing ...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81z4dHAM0kL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 12, 'global_position': 12},
#    'asin': 'B07G783R7X',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 3305, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B07G783R7X',
#    'score': '15203.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Blood Glucose Monitor Kit - Diabetes Testing Kit with 1 Glucometer, 50 Blood Sugar Test Strips, 1 Lancing Device, 100 Lanc...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61beSkSObWL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 13, 'global_position': 13},
#    'asin': 'B007TMMLQ8',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 380, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B007TMMLQ8',
#    'score': '1748.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Assure Platinum Glucose Test Strips for Meter 50ct',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71s3On-q+XL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 14, 'global_position': 14},
#    'asin': '3222034524',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 20, 'rating': 5},
#    'url': 'https://www.amazon.com/dp/3222034524',
#    'score': '100.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Accu-Chek Performa 100 Test Strips Without 222 Code Chip For Glucometer(White)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/513hJjbXfxL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 15, 'global_position': 15},
#    'asin': 'B09KC4TXZ7',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 91, 'rating': 4},
#    'url': 'https://www.amazon.com/dp/B09KC4TXZ7',
#    'score': '364.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Blood Sugar Test Kit, Diabetes Testing Kit with 100 Test Strips and 100 Lancets, Blood Glucose Monitor Kit with Lancing De...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71fj8T3pULL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 16, 'global_position': 16},
#    'asin': 'B06XD7NG87',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 16.73,
#     'savings_amount': 16.73,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 494, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B06XD7NG87',
#    'score': '2371.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'McKesson TRUE METRIX Self-Monitoring Blood Glucose Test Strips, 50 Strips, 1 Pack',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71mtYMukNEL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 17, 'global_position': 17},
#    'asin': 'B01L2LODVM',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1405, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B01L2LODVM',
#    'score': '6744.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': '4 x 50ct TRUE METRIX® NFRS Test Strips (200 Test Strips)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71xY+7zU1CL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 18, 'global_position': 18},
#    'asin': 'B07B6LYFV4',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 29.1,
#     'savings_amount': 29.1,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 4435, 'rating': 4.2},
#    'url': 'https://www.amazon.com/dp/B07B6LYFV4',
#    'score': '18627.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Accu-Chek Instant S Glucometer with Free Test Strips, 10 Count (White)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/51dw+HAuDiL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 19, 'global_position': 19},
#    'asin': 'B093GK1VYD',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 44, 'rating': 4.5},
#    'url': 'https://www.amazon.com/dp/B093GK1VYD',
#    'score': '198.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Blood Glucose Monitor - Diabetes Testing Kit with 100 Test Strips and 100 Lancets - Blood Glucose Meter with Lancing Devic...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71pre-8ou3S._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 20, 'global_position': 20},
#    'asin': 'B073V38KDK',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 51,
#     'savings_amount': 51,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 1207, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B073V38KDK',
#    'score': '5793.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'FreeStyle Precision Neo Blood Glucose Test Strips - 50 ct, Pack of 2',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61SGOpuMNPL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 21, 'global_position': 21},
#    'asin': 'B07CF8C4VX',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 26.58,
#     'savings_amount': 26.58,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 7047, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B07CF8C4VX',
#    'score': '33825.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': True,
#    'amazonPrime': False,
#    'title': 'CONTOUR NEXT Blood Glucose Test Strips, 70 Count',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81aPkB4QWVL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 22, 'global_position': 22},
#    'asin': 'B01F69L0U8',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1636, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B01F69L0U8',
#    'score': '7852.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Prodigy Test Strip Bundle (300ct)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71mJJbR+oNL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 23, 'global_position': 23},
#    'asin': 'B08L473F6W',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 3290, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B08L473F6W',
#    'score': '15792.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'OneTouch Verio Test Strips for Diabetes Value Pack - 60 Count | Diabetic Test Strips for Blood Sugar Monitor | at Home Sel...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/719i6B5r-2L._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 24, 'global_position': 24},
#    'asin': 'B08GP43SFP',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 329, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B08GP43SFP',
#    'score': '1546.30',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Accu-Chek Softclix Diabetes Starter Kit for Blood Glucose Testing',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61kUuJs+3UL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 25, 'global_position': 25},
#    'asin': 'B075VD1JTW',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 32.49,
#     'savings_amount': 32.49,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 4984, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B075VD1JTW',
#    'score': '23424.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Freestyle lite glucose test strips 50 count',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61CsR+RulpL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 26, 'global_position': 26},
#    'asin': 'B08L47PMX6',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 49.99,
#     'savings_amount': 49.99,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 2475, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B08L47PMX6',
#    'score': '11880.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'OneTouch Verio Test Strips for Diabetes Value Pack - 90 Count | Diabetic Test Strips for Blood Sugar Monitor | at Home Sel...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/710wyyf1QDL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 27, 'global_position': 27},
#    'asin': 'B08DXNC949',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1208, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B08DXNC949',
#    'score': '5677.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'TRUE METRIX® Meter Starter Kit',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81tlCfsjL7L._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 28, 'global_position': 28},
#    'asin': 'B00OGXRQWW',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 656, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B00OGXRQWW',
#    'score': '3148.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'GE100 Blood Glucose Test Strips - 4/Boxes of 50 Strips = 200/Total Strips',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71tbZohociL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 29, 'global_position': 29},
#    'asin': 'B08FV1SVSW',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1616, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B08FV1SVSW',
#    'score': '7595.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'The CONTOUR NEXT ONE Blood Glucose Monitoring System All-in-One Kit for Diabetes',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81wt62hu8kL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 30, 'global_position': 30},
#    'asin': 'B094DRQ926',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 99.99,
#     'savings_amount': 99.99,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 167, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B094DRQ926',
#    'score': '784.90',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'OneTouch Verio Test Strips for Diabetes Value Pack - 180 Count | Diabetic Test Strips for Blood Sugar Monitor | at Home Se...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71gbpZ72bwL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 31, 'global_position': 31},
#    'asin': 'B00CJAVTNQ',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1433, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B00CJAVTNQ',
#    'score': '6878.40',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'CareSens N Blood Glucose Test Strips (50 ct) - Only for CareSens N Family Meter Kits',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61Kn1IzmuXL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 32, 'global_position': 32},
#    'asin': 'B08S6TRYJC',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 974, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B08S6TRYJC',
#    'score': '4480.40',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'On Call Express II Diabetes Testing Kit- Blood Glucose Meter, 100 Blood Test Strips, 1 Lancing Device, 100 30g Lancets, Co...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61AjWGq+eYL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 33, 'global_position': 33},
#    'asin': 'B00NF44GU8',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 878, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B00NF44GU8',
#    'score': '4038.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': False,
#    'title': 'Ultra Test Strips Blue 25 Ct',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71MpYaA-rQL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 34, 'global_position': 34},
#    'asin': 'B01AK8YDE0',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 451, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B01AK8YDE0',
#    'score': '2119.70',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'PetTest Diabetes Blood Glucose Tests Strips for Dogs and Cats for use with PetTest Glucose Monitor (50 Strips)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71G3imbXQwL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 35, 'global_position': 35},
#    'asin': 'B082RSBPT4',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1835, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B082RSBPT4',
#    'score': '8441.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'CareSens N Blood Diabetes Testing Kit with 100 Test Strips, 100 Lancets (30G), 1 Glucose Meter, 1 Control Solution, 1 Lanc...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71Ym9NKP6yL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 36, 'global_position': 36},
#    'asin': 'B01HDWVFHO',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 511, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B01HDWVFHO',
#    'score': '2350.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Contour Next EZ Diabetes Testing Kit | Contour Next EZ Blood Glucose Meter, 50 Contour Next Blood Glucose Test Strips, 50 ...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61O6ef7r0PL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 37, 'global_position': 37},
#    'asin': 'B08FXRYSPG',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 2895, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B08FXRYSPG',
#    'score': '13606.50',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'OneTouch Verio Test Strips for Diabetes - 30 Count | Diabetic Test Strips for Blood Sugar Monitor | at Home Self Glucose M...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/716BlYUe9gL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 38, 'global_position': 38},
#    'asin': 'B01M8KJG0A',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 752, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B01M8KJG0A',
#    'score': '3609.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'TRUETRACK Test Strips 50ct (Pack of 4)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61yn5VPkYAL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 39, 'global_position': 39},
#    'asin': 'B07G3BNXR6',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 9544, 'rating': 4.3},
#    'url': 'https://www.amazon.com/dp/B07G3BNXR6',
#    'score': '41039.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'DARIO Blood Glucose Monitor Kit Test Your Blood Sugar Levels and Estimate A1c After 3m. Kit Includes: Glucose-Meter with 2...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61oi8JnoYMS._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 40, 'global_position': 40},
#    'asin': 'B085WBVJZZ',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 24,
#     'savings_amount': 24,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 10549, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B085WBVJZZ',
#    'score': '50635.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'TRUE METRIX Blood Glucose Test Strips NFRS 100ct (100 Test Strips)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/819izUDe3BL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 41, 'global_position': 41},
#    'asin': 'B09V4V9QYN',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 17, 'rating': 3.6},
#    'url': 'https://www.amazon.com/dp/B09V4V9QYN',
#    'score': '61.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Blood Glucose Monitor Kit, 100 Counts 30 Gauge Lancets, 100 Blood Test Strips and Carrying Case, Lancing Device, Control S...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81mFHgENQCL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 42, 'global_position': 42},
#    'asin': 'B077J3XDDW',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 39.99,
#     'savings_amount': 39.99,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 428, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B077J3XDDW',
#    'score': '1968.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'FORA Pro Voice V9 Diabetes Testing Kit for Accurate and Easy Monitoring Your Blood Glucose with Talking Glucometer, 1 Mete...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81AxNHOMtiS._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 43, 'global_position': 43},
#    'asin': 'B00NOKWZLK',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1680, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B00NOKWZLK',
#    'score': '7896.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'On Call Express Blood Glucose Test Strips (50 Count)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/61PiP7cEYBL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 44, 'global_position': 44},
#    'asin': 'B06XRKP8JW',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 1483, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B06XRKP8JW',
#    'score': '6821.80',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'iHealth Blood Glucose Test Strips (50 Count), No Coding Blood Sugar Test, Eligible for FSA Reimbursement, Precision Sugar ...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71t0Yd6NXoL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 45, 'global_position': 45},
#    'asin': 'B07S2T64BL',
#    'price': {'discounted': True,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 22.95,
#     'savings_amount': 22.95,
#     'savings_percent': 100},
#    'reviews': {'total_reviews': 4077, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B07S2T64BL',
#    'score': '18754.20',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Prodigy Glucose Monitor Kit - Includes Prodigy Meter, 100ct test strips, 10ct Lancets, Lancing device, Carrying Case, Log ...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81pIy+MJ1nL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 46, 'global_position': 46},
#    'asin': 'B00NG0MSPQ',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 2785, 'rating': 4.6},
#    'url': 'https://www.amazon.com/dp/B00NG0MSPQ',
#    'score': '12811.00',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'Contour Next EZ Diabetes Testing Kit | Contour Next EZ Blood Glucose Meter, 100 Contour Next Blood Glucose Test Strips, 10...',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71VxBax5LyL._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 47, 'global_position': 47},
#    'asin': 'B01LW1A51V',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 3207, 'rating': 4.8},
#    'url': 'https://www.amazon.com/dp/B01LW1A51V',
#    'score': '15393.60',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': '6 x 50 ct TRUE METRIX® NFRS Test Strips (300 Test Strips)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/71ehsIk4x2L._AC_UL320_.jpg'},
#   {'position': {'page': 1, 'position': 48, 'global_position': 48},
#    'asin': 'B08G5CW8RF',
#    'price': {'discounted': False,
#     'current_price': 0,
#     'currency': 'USD',
#     'before_price': 0,
#     'savings_amount': 0,
#     'savings_percent': 0},
#    'reviews': {'total_reviews': 3521, 'rating': 4.7},
#    'url': 'https://www.amazon.com/dp/B08G5CW8RF',
#    'score': '16548.70',
#    'sponsored': False,
#    'amazonChoice': False,
#    'bestSeller': False,
#    'amazonPrime': True,
#    'title': 'KETO-MOJO Test Strip Combo Pack for Use ONLY with The New GK+ Meter | 60 Blood Glucose + 60 Blood Ketone (120ct)',
#    'thumbnail': 'https://m.media-amazon.com/images/I/81YAcc5V76L._AC_UL320_.jpg'}]}

# %%
df = pd.json_normalize(response, record_path =['result'])
df
# Out:
#           asin                                   url      score  sponsored  \
# 0   B076VSN7TR  https://www.amazon.com/dp/B076VSN7TR  124264.40      False
# 1   B06WD5HRM8  https://www.amazon.com/dp/B06WD5HRM8    5322.20      False
# 2   B087NPJX1W  https://www.amazon.com/dp/B087NPJX1W   28358.40      False
# 3   B07VB22PNT  https://www.amazon.com/dp/B07VB22PNT    2707.20      False
# 4   B07TVLNL4Q  https://www.amazon.com/dp/B07TVLNL4Q   32453.00      False
# 5   B0794DFH6F  https://www.amazon.com/dp/B0794DFH6F   45470.40      False
# 6   B079NSYQN3  https://www.amazon.com/dp/B079NSYQN3    7300.80      False
# 7   B07KCDCBFC  https://www.amazon.com/dp/B07KCDCBFC    2508.00      False
# 8   B07Z3RX8F1  https://www.amazon.com/dp/B07Z3RX8F1   18196.80      False
# 9   B081ZY1LHV  https://www.amazon.com/dp/B081ZY1LHV   14582.00      False
# 10  B07Y1C68K7  https://www.amazon.com/dp/B07Y1C68K7    2212.60      False
# 11  B07G783R7X  https://www.amazon.com/dp/B07G783R7X   15203.00      False
# 12  B007TMMLQ8  https://www.amazon.com/dp/B007TMMLQ8    1748.00      False
# 13  3222034524  https://www.amazon.com/dp/3222034524     100.00      False
# 14  B09KC4TXZ7  https://www.amazon.com/dp/B09KC4TXZ7     364.00      False
# 15  B06XD7NG87  https://www.amazon.com/dp/B06XD7NG87    2371.20      False
# 16  B01L2LODVM  https://www.amazon.com/dp/B01L2LODVM    6744.00      False
# 17  B07B6LYFV4  https://www.amazon.com/dp/B07B6LYFV4   18627.00      False
# 18  B093GK1VYD  https://www.amazon.com/dp/B093GK1VYD     198.00      False
# 19  B073V38KDK  https://www.amazon.com/dp/B073V38KDK    5793.60      False
# 20  B07CF8C4VX  https://www.amazon.com/dp/B07CF8C4VX   33825.60      False
# 21  B01F69L0U8  https://www.amazon.com/dp/B01F69L0U8    7852.80      False
# 22  B08L473F6W  https://www.amazon.com/dp/B08L473F6W   15792.00      False
# 23  B08GP43SFP  https://www.amazon.com/dp/B08GP43SFP    1546.30      False
# 24  B075VD1JTW  https://www.amazon.com/dp/B075VD1JTW   23424.80      False
# 25  B08L47PMX6  https://www.amazon.com/dp/B08L47PMX6   11880.00      False
# 26  B08DXNC949  https://www.amazon.com/dp/B08DXNC949    5677.60      False
# 27  B00OGXRQWW  https://www.amazon.com/dp/B00OGXRQWW    3148.80      False
# 28  B08FV1SVSW  https://www.amazon.com/dp/B08FV1SVSW    7595.20      False
# 29  B094DRQ926  https://www.amazon.com/dp/B094DRQ926     784.90      False
# 30  B00CJAVTNQ  https://www.amazon.com/dp/B00CJAVTNQ    6878.40      False
# 31  B08S6TRYJC  https://www.amazon.com/dp/B08S6TRYJC    4480.40      False
# 32  B00NF44GU8  https://www.amazon.com/dp/B00NF44GU8    4038.80      False
# 33  B01AK8YDE0  https://www.amazon.com/dp/B01AK8YDE0    2119.70      False
# 34  B082RSBPT4  https://www.amazon.com/dp/B082RSBPT4    8441.00      False
# 35  B01HDWVFHO  https://www.amazon.com/dp/B01HDWVFHO    2350.60      False
# 36  B08FXRYSPG  https://www.amazon.com/dp/B08FXRYSPG   13606.50      False
# 37  B01M8KJG0A  https://www.amazon.com/dp/B01M8KJG0A    3609.60      False
# 38  B07G3BNXR6  https://www.amazon.com/dp/B07G3BNXR6   41039.20      False
# 39  B085WBVJZZ  https://www.amazon.com/dp/B085WBVJZZ   50635.20      False
# 40  B09V4V9QYN  https://www.amazon.com/dp/B09V4V9QYN      61.20      False
# 41  B077J3XDDW  https://www.amazon.com/dp/B077J3XDDW    1968.80      False
# 42  B00NOKWZLK  https://www.amazon.com/dp/B00NOKWZLK    7896.00      False
# 43  B06XRKP8JW  https://www.amazon.com/dp/B06XRKP8JW    6821.80      False
# 44  B07S2T64BL  https://www.amazon.com/dp/B07S2T64BL   18754.20      False
# 45  B00NG0MSPQ  https://www.amazon.com/dp/B00NG0MSPQ   12811.00      False
# 46  B01LW1A51V  https://www.amazon.com/dp/B01LW1A51V   15393.60      False
# 47  B08G5CW8RF  https://www.amazon.com/dp/B08G5CW8RF   16548.70      False
#
#     amazonChoice  bestSeller  amazonPrime  \
# 0          False        True         True
# 1          False       False        False
# 2          False       False        False
# 3          False       False         True
# 4          False       False         True
# 5          False       False         True
# 6          False       False         True
# 7          False       False         True
# 8          False       False         True
# 9          False       False         True
# 10         False       False        False
# 11         False       False        False
# 12         False       False        False
# 13         False       False         True
# 14         False       False         True
# 15         False       False        False
# 16         False       False        False
# 17         False       False         True
# 18         False       False         True
# 19         False       False        False
# 20         False        True        False
# 21         False       False        False
# 22         False       False         True
# 23         False       False        False
# 24         False       False        False
# 25         False       False        False
# 26         False       False         True
# 27         False       False        False
# 28         False       False         True
# 29         False       False        False
# 30         False       False         True
# 31         False       False         True
# 32         False       False        False
# 33         False       False         True
# 34         False       False         True
# 35         False       False         True
# 36         False       False         True
# 37         False       False         True
# 38         False       False         True
# 39         False       False         True
# 40         False       False         True
# 41         False       False         True
# 42         False       False         True
# 43         False       False         True
# 44         False       False         True
# 45         False       False         True
# 46         False       False         True
# 47         False       False         True
#
#                                                 title  \
# 0   Blood Glucose Monitor Kit - Diabetes Testing K...
# 1   Easy Touch Eas-150 Easytouch Glucose Test Stri...
# 2   Accu-Chek Guide Test Strips for Diabetic Blood...
# 3   Metene TD-4116 Blood Glucose Test Strips, 100 ...
# 4   AUVON Blood Sugar Test Kit, High-Tech Glucose ...
# 5   Care Touch Blood Glucose Test Strips for Diabe...
# 6   5 x 50ct TRUE METRIX® NFRS Test Strips (250 Te...
# 7   Reliable Diathrive Blood Sugar Test Kit & Bloo...
# 8   AUVON I-QARE DS-W Draw-in Blood Glucose Test S...
# 9   AUVON High-Tech Blood Sugar Test Kit, Diabetes...
# 10  OneTouch Ultra 2 Blood Glucose Meter | Glucose...
# 11  Blood Glucose Monitor Kit - Diabetes Testing K...
# 12  Assure Platinum Glucose Test Strips for Meter ...
# 13  Accu-Chek Performa 100 Test Strips Without 222...
# 14  Blood Sugar Test Kit, Diabetes Testing Kit wit...
# 15  McKesson TRUE METRIX Self-Monitoring Blood Glu...
# 16  4 x 50ct TRUE METRIX® NFRS Test Strips (200 Te...
# 17  Accu-Chek Instant S Glucometer with Free Test ...
# 18  Blood Glucose Monitor - Diabetes Testing Kit w...
# 19  FreeStyle Precision Neo Blood Glucose Test Str...
# 20   CONTOUR NEXT Blood Glucose Test Strips, 70 Count
# 21                  Prodigy Test Strip Bundle (300ct)
# 22  OneTouch Verio Test Strips for Diabetes Value ...
# 23  Accu-Chek Softclix Diabetes Starter Kit for Bl...
# 24        Freestyle lite glucose test strips 50 count
# 25  OneTouch Verio Test Strips for Diabetes Value ...
# 26                     TRUE METRIX® Meter Starter Kit
# 27  GE100 Blood Glucose Test Strips - 4/Boxes of 5...
# 28  The CONTOUR NEXT ONE Blood Glucose Monitoring ...
# 29  OneTouch Verio Test Strips for Diabetes Value ...
# 30  CareSens N Blood Glucose Test Strips (50 ct) -...
# 31  On Call Express II Diabetes Testing Kit- Blood...
# 32                       Ultra Test Strips Blue 25 Ct
# 33  PetTest Diabetes Blood Glucose Tests Strips fo...
# 34  CareSens N Blood Diabetes Testing Kit with 100...
# 35  Contour Next EZ Diabetes Testing Kit | Contour...
# 36  OneTouch Verio Test Strips for Diabetes - 30 C...
# 37             TRUETRACK Test Strips 50ct (Pack of 4)
# 38  DARIO Blood Glucose Monitor Kit Test Your Bloo...
# 39  TRUE METRIX Blood Glucose Test Strips NFRS 100...
# 40  Blood Glucose Monitor Kit, 100 Counts 30 Gauge...
# 41  FORA Pro Voice V9 Diabetes Testing Kit for Acc...
# 42  On Call Express Blood Glucose Test Strips (50 ...
# 43  iHealth Blood Glucose Test Strips (50 Count), ...
# 44  Prodigy Glucose Monitor Kit - Includes Prodigy...
# 45  Contour Next EZ Diabetes Testing Kit | Contour...
# 46  6 x 50 ct TRUE METRIX® NFRS Test Strips (300 T...
# 47  KETO-MOJO Test Strip Combo Pack for Use ONLY w...
#
#                                             thumbnail  position.page  \
# 0   https://m.media-amazon.com/images/I/81EZb2+YuK...              1
# 1   https://m.media-amazon.com/images/I/51wBoCNWj3...              1
# 2   https://m.media-amazon.com/images/I/71imFW8YsA...              1
# 3   https://m.media-amazon.com/images/I/71160PqPGP...              1
# 4   https://m.media-amazon.com/images/I/71V3ihtTar...              1
# 5   https://m.media-amazon.com/images/I/71xi00Rr7W...              1
# 6   https://m.media-amazon.com/images/I/71r0dsIfBs...              1
# 7   https://m.media-amazon.com/images/I/81uFA6SNCw...              1
# 8   https://m.media-amazon.com/images/I/71oxRLoqjp...              1
# 9   https://m.media-amazon.com/images/I/81qIlUsuT9...              1
# 10  https://m.media-amazon.com/images/I/81z4dHAM0k...              1
# 11  https://m.media-amazon.com/images/I/61beSkSObW...              1
# 12  https://m.media-amazon.com/images/I/71s3On-q+X...              1
# 13  https://m.media-amazon.com/images/I/513hJjbXfx...              1
# 14  https://m.media-amazon.com/images/I/71fj8T3pUL...              1
# 15  https://m.media-amazon.com/images/I/71mtYMukNE...              1
# 16  https://m.media-amazon.com/images/I/71xY+7zU1C...              1
# 17  https://m.media-amazon.com/images/I/51dw+HAuDi...              1
# 18  https://m.media-amazon.com/images/I/71pre-8ou3...              1
# 19  https://m.media-amazon.com/images/I/61SGOpuMNP...              1
# 20  https://m.media-amazon.com/images/I/81aPkB4QWV...              1
# 21  https://m.media-amazon.com/images/I/71mJJbR+oN...              1
# 22  https://m.media-amazon.com/images/I/719i6B5r-2...              1
# 23  https://m.media-amazon.com/images/I/61kUuJs+3U...              1
# 24  https://m.media-amazon.com/images/I/61CsR+Rulp...              1
# 25  https://m.media-amazon.com/images/I/710wyyf1QD...              1
# 26  https://m.media-amazon.com/images/I/81tlCfsjL7...              1
# 27  https://m.media-amazon.com/images/I/71tbZohoci...              1
# 28  https://m.media-amazon.com/images/I/81wt62hu8k...              1
# 29  https://m.media-amazon.com/images/I/71gbpZ72bw...              1
# 30  https://m.media-amazon.com/images/I/61Kn1IzmuX...              1
# 31  https://m.media-amazon.com/images/I/61AjWGq+eY...              1
# 32  https://m.media-amazon.com/images/I/71MpYaA-rQ...              1
# 33  https://m.media-amazon.com/images/I/71G3imbXQw...              1
# 34  https://m.media-amazon.com/images/I/71Ym9NKP6y...              1
# 35  https://m.media-amazon.com/images/I/61O6ef7r0P...              1
# 36  https://m.media-amazon.com/images/I/716BlYUe9g...              1
# 37  https://m.media-amazon.com/images/I/61yn5VPkYA...              1
# 38  https://m.media-amazon.com/images/I/61oi8JnoYM...              1
# 39  https://m.media-amazon.com/images/I/819izUDe3B...              1
# 40  https://m.media-amazon.com/images/I/81mFHgENQC...              1
# 41  https://m.media-amazon.com/images/I/81AxNHOMti...              1
# 42  https://m.media-amazon.com/images/I/61PiP7cEYB...              1
# 43  https://m.media-amazon.com/images/I/71t0Yd6NXo...              1
# 44  https://m.media-amazon.com/images/I/81pIy+MJ1n...              1
# 45  https://m.media-amazon.com/images/I/71VxBax5Ly...              1
# 46  https://m.media-amazon.com/images/I/71ehsIk4x2...              1
# 47  https://m.media-amazon.com/images/I/81YAcc5V76...              1
#
#     position.position  position.global_position  price.discounted  \
# 0                   1                         1             False
# 1                   2                         2             False
# 2                   3                         3             False
# 3                   4                         4             False
# 4                   5                         5              True
# 5                   6                         6             False
# 6                   7                         7              True
# 7                   8                         8             False
# 8                   9                         9             False
# 9                  10                        10              True
# 10                 11                        11             False
# 11                 12                        12             False
# 12                 13                        13             False
# 13                 14                        14             False
# 14                 15                        15             False
# 15                 16                        16              True
# 16                 17                        17             False
# 17                 18                        18              True
# 18                 19                        19             False
# 19                 20                        20              True
# 20                 21                        21              True
# 21                 22                        22             False
# 22                 23                        23             False
# 23                 24                        24             False
# 24                 25                        25              True
# 25                 26                        26              True
# 26                 27                        27             False
# 27                 28                        28             False
# 28                 29                        29             False
# 29                 30                        30              True
# 30                 31                        31             False
# 31                 32                        32             False
# 32                 33                        33             False
# 33                 34                        34             False
# 34                 35                        35             False
# 35                 36                        36             False
# 36                 37                        37             False
# 37                 38                        38             False
# 38                 39                        39             False
# 39                 40                        40              True
# 40                 41                        41             False
# 41                 42                        42              True
# 42                 43                        43             False
# 43                 44                        44             False
# 44                 45                        45              True
# 45                 46                        46             False
# 46                 47                        47             False
# 47                 48                        48             False
#
#     price.current_price price.currency  price.before_price  \
# 0                     0            USD                0.00
# 1                     0            USD                0.00
# 2                     0            USD                0.00
# 3                     0            USD                0.00
# 4                     0            USD               28.99
# 5                     0            USD                0.00
# 6                     0            USD               50.00
# 7                     0            USD                0.00
# 8                     0            USD                0.00
# 9                     0            USD               35.99
# 10                    0            USD                0.00
# 11                    0            USD                0.00
# 12                    0            USD                0.00
# 13                    0            USD                0.00
# 14                    0            USD                0.00
# 15                    0            USD               16.73
# 16                    0            USD                0.00
# 17                    0            USD               29.10
# 18                    0            USD                0.00
# 19                    0            USD               51.00
# 20                    0            USD               26.58
# 21                    0            USD                0.00
# 22                    0            USD                0.00
# 23                    0            USD                0.00
# 24                    0            USD               32.49
# 25                    0            USD               49.99
# 26                    0            USD                0.00
# 27                    0            USD                0.00
# 28                    0            USD                0.00
# 29                    0            USD               99.99
# 30                    0            USD                0.00
# 31                    0            USD                0.00
# 32                    0            USD                0.00
# 33                    0            USD                0.00
# 34                    0            USD                0.00
# 35                    0            USD                0.00
# 36                    0            USD                0.00
# 37                    0            USD                0.00
# 38                    0            USD                0.00
# 39                    0            USD               24.00
# 40                    0            USD                0.00
# 41                    0            USD               39.99
# 42                    0            USD                0.00
# 43                    0            USD                0.00
# 44                    0            USD               22.95
# 45                    0            USD                0.00
# 46                    0            USD                0.00
# 47                    0            USD                0.00
#
#     price.savings_amount  price.savings_percent  reviews.total_reviews  \
# 0                   0.00                      0                  27014
# 1                   0.00                      0                   1157
# 2                   0.00                      0                   5908
# 3                   0.00                      0                    576
# 4                  28.99                    100                   7055
# 5                   0.00                      0                   9473
# 6                  50.00                    100                   1521
# 7                   0.00                      0                    570
# 8                   0.00                      0                   3791
# 9                  35.99                    100                   3170
# 10                  0.00                      0                    481
# 11                  0.00                      0                   3305
# 12                  0.00                      0                    380
# 13                  0.00                      0                     20
# 14                  0.00                      0                     91
# 15                 16.73                    100                    494
# 16                  0.00                      0                   1405
# 17                 29.10                    100                   4435
# 18                  0.00                      0                     44
# 19                 51.00                    100                   1207
# 20                 26.58                    100                   7047
# 21                  0.00                      0                   1636
# 22                  0.00                      0                   3290
# 23                  0.00                      0                    329
# 24                 32.49                    100                   4984
# 25                 49.99                    100                   2475
# 26                  0.00                      0                   1208
# 27                  0.00                      0                    656
# 28                  0.00                      0                   1616
# 29                 99.99                    100                    167
# 30                  0.00                      0                   1433
# 31                  0.00                      0                    974
# 32                  0.00                      0                    878
# 33                  0.00                      0                    451
# 34                  0.00                      0                   1835
# 35                  0.00                      0                    511
# 36                  0.00                      0                   2895
# 37                  0.00                      0                    752
# 38                  0.00                      0                   9544
# 39                 24.00                    100                  10549
# 40                  0.00                      0                     17
# 41                 39.99                    100                    428
# 42                  0.00                      0                   1680
# 43                  0.00                      0                   1483
# 44                 22.95                    100                   4077
# 45                  0.00                      0                   2785
# 46                  0.00                      0                   3207
# 47                  0.00                      0                   3521
#
#     reviews.rating
# 0              4.6
# 1              4.6
# 2              4.8
# 3              4.7
# 4              4.6
# 5              4.8
# 6              4.8
# 7              4.4
# 8              4.8
# 9              4.6
# 10             4.6
# 11             4.6
# 12             4.6
# 13             5.0
# 14             4.0
# 15             4.8
# 16             4.8
# 17             4.2
# 18             4.5
# 19             4.8
# 20             4.8
# 21             4.8
# 22             4.8
# 23             4.7
# 24             4.7
# 25             4.8
# 26             4.7
# 27             4.8
# 28             4.7
# 29             4.7
# 30             4.8
# 31             4.6
# 32             4.6
# 33             4.7
# 34             4.6
# 35             4.6
# 36             4.7
# 37             4.8
# 38             4.3
# 39             4.8
# 40             3.6
# 41             4.6
# 42             4.7
# 43             4.6
# 44             4.6
# 45             4.6
# 46             4.8
# 47             4.7

# %%
for x in range(2,6):
    url = "https://amazon23.p.rapidapi.com/product-search"

    querystring = {"query":"glucometer test strips","page":x,"country":"US"}

    headers = {
        "X-RapidAPI-Host": "amazon23.p.rapidapi.com",
        "X-RapidAPI-Key": "f0470787e2msh2927b433c937eaep1a36a6jsn7ecc0efa9865"
    }

    response = requests.request("GET", url, headers=headers, params=querystring).json()

    df2 = pd.json_normalize(response, record_path =['result'])
    df = df.append(df2, ignore_index=True)

# %%
df
# Out:
#            asin                                   url      score  sponsored  \
# 0    B076VSN7TR  https://www.amazon.com/dp/B076VSN7TR  124264.40      False
# 1    B06WD5HRM8  https://www.amazon.com/dp/B06WD5HRM8    5322.20      False
# 2    B087NPJX1W  https://www.amazon.com/dp/B087NPJX1W   28358.40      False
# 3    B07VB22PNT  https://www.amazon.com/dp/B07VB22PNT    2707.20      False
# 4    B07TVLNL4Q  https://www.amazon.com/dp/B07TVLNL4Q   32453.00      False
# ..          ...                                   ...        ...        ...
# 203  B008MU09EC  https://www.amazon.com/dp/B008MU09EC     409.40      False
# 204  B00QH65O48  https://www.amazon.com/dp/B00QH65O48     662.40      False
# 205  B01GU3SKZM  https://www.amazon.com/dp/B01GU3SKZM    4213.60      False
# 206  B093GK1VYD  https://www.amazon.com/dp/B093GK1VYD     198.00      False
# 207  B00KBZ4Y5G  https://www.amazon.com/dp/B00KBZ4Y5G     931.50      False
#
#      amazonChoice  bestSeller  amazonPrime  \
# 0           False        True         True
# 1           False       False        False
# 2           False       False        False
# 3           False       False         True
# 4           False       False         True
# ..            ...         ...          ...
# 203         False       False        False
# 204         False       False        False
# 205         False       False        False
# 206         False       False         True
# 207         False       False        False
#
#                                                  title  \
# 0    Blood Glucose Monitor Kit - Diabetes Testing K...
# 1    Easy Touch Eas-150 Easytouch Glucose Test Stri...
# 2    Accu-Chek Guide Test Strips for Diabetic Blood...
# 3    Metene TD-4116 Blood Glucose Test Strips, 100 ...
# 4    AUVON Blood Sugar Test Kit, High-Tech Glucose ...
# ..                                                 ...
# 203  Diabetes Testing Kit Glucose Testing Kit inclu...
# 204  Abbott Freestyle Lite Blood Glucose Meter with...
# 205  True Decor TrueMetrix Self Monitoring Blood Gl...
# 206  Sponsored Ad - Blood Glucose Monitor - Diabete...
# 207  Sponsored Ad - A1CNow+ System (Monitor w/20 St...
#
#                                              thumbnail  position.page  \
# 0    https://m.media-amazon.com/images/I/81EZb2+YuK...              1
# 1    https://m.media-amazon.com/images/I/51wBoCNWj3...              1
# 2    https://m.media-amazon.com/images/I/71imFW8YsA...              1
# 3    https://m.media-amazon.com/images/I/71160PqPGP...              1
# 4    https://m.media-amazon.com/images/I/71V3ihtTar...              1
# ..                                                 ...            ...
# 203  https://m.media-amazon.com/images/I/51CQA4fxkN...              1
# 204  https://m.media-amazon.com/images/I/61Xpt4QmBu...              1
# 205  https://m.media-amazon.com/images/I/810RZIxG3q...              1
# 206  https://m.media-amazon.com/images/I/71pre-8ou3...              1
# 207  https://m.media-amazon.com/images/I/310x7pg7FI...              1
#
#      position.position  position.global_position  price.discounted  \
# 0                    1                         1             False
# 1                    2                         2             False
# 2                    3                         3             False
# 3                    4                         4             False
# 4                    5                         5              True
# ..                 ...                       ...               ...
# 203                 52                        52             False
# 204                 53                        53             False
# 205                 55                        55              True
# 206                 56                        56             False
# 207                 57                        57             False
#
#      price.current_price price.currency  price.before_price  \
# 0                      0            USD                0.00
# 1                      0            USD                0.00
# 2                      0            USD                0.00
# 3                      0            USD                0.00
# 4                      0            USD               28.99
# ..                   ...            ...                 ...
# 203                    0            USD                0.00
# 204                    0            USD                0.00
# 205                    0            USD               10.80
# 206                    0            USD                0.00
# 207                    0            USD                0.00
#
#      price.savings_amount  price.savings_percent  reviews.total_reviews  \
# 0                    0.00                      0                  27014
# 1                    0.00                      0                   1157
# 2                    0.00                      0                   5908
# 3                    0.00                      0                    576
# 4                   28.99                    100                   7055
# ..                    ...                    ...                    ...
# 203                  0.00                      0                     89
# 204                  0.00                      0                    144
# 205                 10.80                    100                    916
# 206                  0.00                      0                     44
# 207                  0.00                      0                    207
#
#      reviews.rating
# 0               4.6
# 1               4.6
# 2               4.8
# 3               4.7
# 4               4.6
# ..              ...
# 203             4.6
# 204             4.6
# 205             4.6
# 206             4.5
# 207             4.5
#
# [208 rows x 20 columns]

# %%
df.to_csv("glucometer_review_raw.csv", index=False, header=True)
